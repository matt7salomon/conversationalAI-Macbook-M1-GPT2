# %%
pip install transformers torch sounddevice speechrecognition pyttsx3
# Out:
# Requirement already satisfied: transformers in /opt/miniconda3/lib/python3.12/site-packages (4.47.1)
# Requirement already satisfied: torch in /opt/miniconda3/lib/python3.12/site-packages (2.5.1)
# Collecting sounddevice
#   Downloading sounddevice-0.5.1-py3-none-macosx_10_6_x86_64.macosx_10_6_universal2.whl.metadata (1.4 kB)
# Collecting speechrecognition
#   Downloading SpeechRecognition-3.14.1-py3-none-any.whl.metadata (31 kB)
# Collecting pyttsx3
#   Downloading pyttsx3-2.98-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: filelock in /opt/miniconda3/lib/python3.12/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /opt/miniconda3/lib/python3.12/site-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /opt/miniconda3/lib/python3.12/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/lib/python3.12/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/miniconda3/lib/python3.12/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/miniconda3/lib/python3.12/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /opt/miniconda3/lib/python3.12/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/miniconda3/lib/python3.12/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/miniconda3/lib/python3.12/site-packages (from transformers) (0.5.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/miniconda3/lib/python3.12/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/miniconda3/lib/python3.12/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /opt/miniconda3/lib/python3.12/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/miniconda3/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/miniconda3/lib/python3.12/site-packages (from torch) (2024.9.0)
# Requirement already satisfied: setuptools in /opt/miniconda3/lib/python3.12/site-packages (from torch) (72.1.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/miniconda3/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/miniconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: CFFI>=1.0 in /opt/miniconda3/lib/python3.12/site-packages (from sounddevice) (1.17.1)
# Collecting pyobjc>=2.4 (from pyttsx3)
#   Downloading pyobjc-11.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pycparser in /opt/miniconda3/lib/python3.12/site-packages (from CFFI>=1.0->sounddevice) (2.21)
# Requirement already satisfied: pyobjc-core==11.0 in /opt/miniconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Collecting pyobjc-framework-libdispatch==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_libdispatch-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-libxpc==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_libxpc-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-Accessibility==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_Accessibility-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-AdServices==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_AdServices-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AdSupport==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_AdSupport-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AppTrackingTransparency==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_AppTrackingTransparency-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AudioVideoBridging==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_AudioVideoBridging-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-AuthenticationServices==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_AuthenticationServices-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-AutomaticAssessmentConfiguration==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_AutomaticAssessmentConfiguration-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-AVKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_AVKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-AVFoundation==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_AVFoundation-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-AVRouting==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_AVRouting-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-Accounts==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_Accounts-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AddressBook==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_AddressBook-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-AppleScriptKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_AppleScriptKit-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AppleScriptObjC==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_AppleScriptObjC-11.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pyobjc-framework-ApplicationServices==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ApplicationServices-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-Automator==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_Automator-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-BackgroundAssets==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_BackgroundAssets-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-BrowserEngineKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_BrowserEngineKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-BusinessChat==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_BusinessChat-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-CFNetwork==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CFNetwork-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-CalendarStore==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CalendarStore-11.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pyobjc-framework-CallKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CallKit-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-Carbon==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_Carbon-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-Cinematic==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_Cinematic-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-ClassKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ClassKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-CloudKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CloudKit-11.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pyobjc-framework-Cocoa==11.0 in /opt/miniconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Collecting pyobjc-framework-Collaboration==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_Collaboration-11.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pyobjc-framework-ColorSync==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ColorSync-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-Contacts==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_Contacts-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-ContactsUI==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ContactsUI-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-CoreAudio==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CoreAudio-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-CoreAudioKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CoreAudioKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-CoreBluetooth==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CoreBluetooth-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-CoreData==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CoreData-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-CoreHaptics==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CoreHaptics-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-CoreLocation==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CoreLocation-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-CoreMedia==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CoreMedia-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-CoreMediaIO==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CoreMediaIO-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-CoreMIDI==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CoreMIDI-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-CoreML==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CoreML-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-CoreMotion==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CoreMotion-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-CoreServices==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CoreServices-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-CoreSpotlight==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CoreSpotlight-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-CoreText==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CoreText-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-CoreWLAN==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CoreWLAN-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-CryptoTokenKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_CryptoTokenKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-DataDetection==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_DataDetection-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-DeviceCheck==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_DeviceCheck-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-DeviceDiscoveryExtension==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_DeviceDiscoveryExtension-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-DictionaryServices==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_DictionaryServices-11.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-DiscRecording==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_DiscRecording-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-DiscRecordingUI==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_DiscRecordingUI-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-DiskArbitration==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_DiskArbitration-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-DVDPlayback==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_DVDPlayback-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-EventKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_EventKit-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-ExceptionHandling==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ExceptionHandling-11.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting pyobjc-framework-ExecutionPolicy==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ExecutionPolicy-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-ExternalAccessory==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ExternalAccessory-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-ExtensionKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ExtensionKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-FileProvider==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_FileProvider-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-FileProviderUI==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_FileProviderUI-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-FSEvents==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_FSEvents-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-FinderSync==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_FinderSync-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-GameCenter==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_GameCenter-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-GameController==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_GameController-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-HealthKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_HealthKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-InputMethodKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_InputMethodKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-ImageCaptureCore==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ImageCaptureCore-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-Intents==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_Intents-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-IntentsUI==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_IntentsUI-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-InstallerPlugins==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_InstallerPlugins-11.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pyobjc-framework-InstantMessage==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_InstantMessage-11.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting pyobjc-framework-IOBluetooth==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_IOBluetooth-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-IOBluetoothUI==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_IOBluetoothUI-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-IOSurface==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_IOSurface-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-KernelManagement==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_KernelManagement-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-LatentSemanticMapping==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_LatentSemanticMapping-11.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting pyobjc-framework-LaunchServices==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_LaunchServices-11.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-LinkPresentation==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_LinkPresentation-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-LocalAuthentication==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_LocalAuthentication-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-LocalAuthenticationEmbeddedUI==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_LocalAuthenticationEmbeddedUI-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-MailKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_MailKit-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-MapKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_MapKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-MediaAccessibility==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_MediaAccessibility-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-MediaExtension==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_MediaExtension-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-MediaLibrary==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_MediaLibrary-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-MediaPlayer==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_MediaPlayer-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-MediaToolbox==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_MediaToolbox-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-Metal==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_Metal-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-MetalFX==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_MetalFX-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-MetalKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_MetalKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-MetalPerformanceShaders==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_MetalPerformanceShaders-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-MetalPerformanceShadersGraph==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_MetalPerformanceShadersGraph-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-MetricKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_MetricKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-MLCompute==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_MLCompute-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-ModelIO==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ModelIO-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-MultipeerConnectivity==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_MultipeerConnectivity-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-NaturalLanguage==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_NaturalLanguage-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-NetFS==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_NetFS-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-Network==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_Network-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-NetworkExtension==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_NetworkExtension-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-NotificationCenter==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_NotificationCenter-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-OpenDirectory==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_OpenDirectory-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-OSAKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_OSAKit-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-OSLog==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_OSLog-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-PassKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_PassKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-PencilKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_PencilKit-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-PHASE==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_PHASE-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-Photos==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_Photos-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-PhotosUI==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_PhotosUI-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-PreferencePanes==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_PreferencePanes-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-PushKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_PushKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Requirement already satisfied: pyobjc-framework-Quartz==11.0 in /opt/miniconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Collecting pyobjc-framework-QuickLookThumbnailing==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_QuickLookThumbnailing-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-ReplayKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ReplayKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-SafetyKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_SafetyKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-SafariServices==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_SafariServices-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-ScreenSaver==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ScreenSaver-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-ScreenTime==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ScreenTime-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-ScriptingBridge==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ScriptingBridge-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-Security==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_Security-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-SecurityFoundation==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_SecurityFoundation-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-SecurityInterface==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_SecurityInterface-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-SearchKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_SearchKit-11.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-ServiceManagement==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ServiceManagement-11.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pyobjc-framework-ShazamKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ShazamKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-Social==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_Social-11.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-Speech==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_Speech-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-SpriteKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_SpriteKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-StoreKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_StoreKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-SyncServices==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_SyncServices-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-SystemConfiguration==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_SystemConfiguration-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-WebKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_WebKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-GameKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_GameKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-GameplayKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_GameplayKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-SceneKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_SceneKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-SensitiveContentAnalysis==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_SensitiveContentAnalysis-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-SharedWithYouCore==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_SharedWithYouCore-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-SharedWithYou==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_SharedWithYou-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-SoundAnalysis==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_SoundAnalysis-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-ScreenCaptureKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ScreenCaptureKit-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-Symbols==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_Symbols-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-SystemExtensions==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_SystemExtensions-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-ThreadNetwork==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_ThreadNetwork-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-UniformTypeIdentifiers==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_UniformTypeIdentifiers-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-UserNotifications==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_UserNotifications-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-UserNotificationsUI==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_UserNotificationsUI-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-VideoSubscriberAccount==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_VideoSubscriberAccount-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-VideoToolbox==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_VideoToolbox-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-Virtualization==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_Virtualization-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-Vision==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_Vision-11.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-iTunesLibrary==11.0 (from pyobjc>=2.4->pyttsx3)
#   Downloading pyobjc_framework_iTunesLibrary-11.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/lib/python3.12/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/lib/python3.12/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/lib/python3.12/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/lib/python3.12/site-packages (from requests->transformers) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/lib/python3.12/site-packages (from requests->transformers) (2024.8.30)
# Downloading sounddevice-0.5.1-py3-none-macosx_10_6_x86_64.macosx_10_6_universal2.whl (107 kB)
# Downloading SpeechRecognition-3.14.1-py3-none-any.whl (32.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 65.2 MB/s eta 0:00:00a 0:00:01
# Downloading pyttsx3-2.98-py3-none-any.whl (34 kB)
# Downloading pyobjc-11.0-py3-none-any.whl (4.2 kB)
# Downloading pyobjc_framework_Accessibility-11.0-cp312-cp312-macosx_10_13_universal2.whl (10 kB)
# Downloading pyobjc_framework_Accounts-11.0-py3-none-any.whl (5.1 kB)
# Downloading pyobjc_framework_AddressBook-11.0-cp312-cp312-macosx_10_13_universal2.whl (13 kB)
# Downloading pyobjc_framework_AdServices-11.0-py3-none-any.whl (3.5 kB)
# Downloading pyobjc_framework_AdSupport-11.0-py3-none-any.whl (3.4 kB)
# Downloading pyobjc_framework_AppleScriptKit-11.0-py3-none-any.whl (4.3 kB)
# Downloading pyobjc_framework_AppleScriptObjC-11.0-py3-none-any.whl (4.4 kB)
# Downloading pyobjc_framework_ApplicationServices-11.0-cp312-cp312-macosx_10_13_universal2.whl (30 kB)
# Downloading pyobjc_framework_AppTrackingTransparency-11.0-py3-none-any.whl (3.9 kB)
# Downloading pyobjc_framework_AudioVideoBridging-11.0-cp312-cp312-macosx_10_13_universal2.whl (10 kB)
# Downloading pyobjc_framework_AuthenticationServices-11.0-cp312-cp312-macosx_10_13_universal2.whl (20 kB)
# Downloading pyobjc_framework_AutomaticAssessmentConfiguration-11.0-cp312-cp312-macosx_10_13_universal2.whl (9.0 kB)
# Downloading pyobjc_framework_Automator-11.0-cp312-cp312-macosx_10_13_universal2.whl (9.8 kB)
# Downloading pyobjc_framework_AVFoundation-11.0-cp312-cp312-macosx_10_13_universal2.whl (71 kB)
# Downloading pyobjc_framework_AVKit-11.0-cp312-cp312-macosx_10_13_universal2.whl (11 kB)
# Downloading pyobjc_framework_AVRouting-11.0-cp312-cp312-macosx_10_13_universal2.whl (8.1 kB)
# Downloading pyobjc_framework_BackgroundAssets-11.0-cp312-cp312-macosx_10_13_universal2.whl (9.5 kB)
# Downloading pyobjc_framework_BrowserEngineKit-11.0-cp312-cp312-macosx_10_13_universal2.whl (10 kB)
# Downloading pyobjc_framework_BusinessChat-11.0-py3-none-any.whl (3.5 kB)
# ^C
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sounddevice
# Out:
# Requirement already satisfied: sounddevice in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: CFFI>=1.0 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from sounddevice) (1.15.1)
# Requirement already satisfied: pycparser in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from CFFI>=1.0->sounddevice) (2.21)
# WARNING: Error parsing requirements for numpy: [Errno 2] No such file or directory: '/Users/mattsalomon/miniconda3/lib/python3.10/site-packages/numpy-1.23.5.dist-info/METADATA'
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install py3-tts
# Out:
# Requirement already satisfied: py3-tts in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (3.5)
# Requirement already satisfied: pyobjc==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from py3-tts) (9.0.1)
# Requirement already satisfied: six in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from py3-tts) (1.12.0)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MetricKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-GameController==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MetalKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYouCore==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CFNetwork==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreMotion==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SyncServices==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ColorSync==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-OSLog==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-GameplayKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-FileProvider==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-NetFS==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MetalFX==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AddressBook==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Accounts==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-WebKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Collaboration==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-FSEvents==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DataDetection==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ClassKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ModelIO==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SpriteKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-core==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Photos==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MLCompute==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PhotosUI==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-InstantMessage==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-EventKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-BackgroundAssets==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ScreenTime==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-FinderSync==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-libdispatch==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SafetyKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AVRouting==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ThreadNetwork==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Network==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AdSupport==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Contacts==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-OSAKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-IntentsUI==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-IOSurface==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PencilKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MapKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CalendarStore==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-IMServicePlugIn==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SceneKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Virtualization==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Accessibility==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CallKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreLocation==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreML==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Vision==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DiscRecording==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-GameCenter==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-UserNotifications==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Speech==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SearchKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AVKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreText==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AdServices==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-BusinessChat==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Social==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Quartz==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SafariServices==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Cocoa==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-KernelManagement==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ShazamKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreServices==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Security==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-LaunchServices==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MailKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Intents==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Automator==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-GameKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PassKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ExtensionKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CloudKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreData==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-StoreKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ReplayKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYou==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AVFoundation==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Metal==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ContactsUI==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-HealthKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PushKit==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==9.0.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from pyobjc==9.0.1->py3-tts) (9.0.1)
# WARNING: Error parsing requirements for numpy: [Errno 2] No such file or directory: '/Users/mattsalomon/miniconda3/lib/python3.10/site-packages/numpy-1.23.5.dist-info/METADATA'
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import speech_recognition as sr
import pyttsx3
import sounddevice as sd
import numpy as np

# Initialize the text-to-speech engine
engine = pyttsx3.init()

# Set speech rate (optional)
engine.setProperty('rate', 150)

# Check if we can use the GPU on a Mac M1
device = torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")
print(f"Using device: {device}")

# Load the GPT-2 tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2").to(device)
model.eval()

# Speech recognition setup
recognizer = sr.Recognizer()

# Function to convert text to speech
def speak(text):
    engine.say(text)
    engine.runAndWait()

# Function to listen for user input via microphone
def listen():
    with sr.Microphone() as source:
        recognizer.adjust_for_ambient_noise(source)
        print("Listening...")
        audio = recognizer.listen(source)

        try:
            # Recognize the speech
            user_input = recognizer.recognize_google(audio)
            print(f"User: {user_input}")
            return user_input
        except sr.UnknownValueError:
            print("Sorry, I could not understand your speech.")
            return ""
        except sr.RequestError as e:
            print(f"Could not request results from Google Speech Recognition service; {e}")
            return ""

# Function to generate a response using GPT-2
def generate_response(prompt, max_length=100):
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
    outputs = model.generate(inputs, max_length=max_length, pad_token_id=tokenizer.eos_token_id)
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response

# Main conversation loop
def conversation():
    print("Say something to start the conversation (or 'quit' to exit):")
    while True:
        user_input = listen()
        
        if user_input.lower() == "quit":
            print("Exiting...")
            speak("Goodbye!")
            break

        if user_input:
            # Generate AI response
            gpt_response = generate_response(user_input)
            print(f"AI: {gpt_response}")
            
            # Convert response to speech
            speak(gpt_response)

if __name__ == "__main__":
    conversation()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import torch
# ----> 2 from transformers import GPT2Tokenizer, GPT2LMHeadModel
#       3 import speech_recognition as sr
#       4 import pyttsx3
#
# File /opt/miniconda3/lib/python3.12/site-packages/transformers/__init__.py:26
#      23 from typing import TYPE_CHECKING
#      25 # Check the dependencies satisfy the minimal versions required.
# ---> 26 from . import dependency_versions_check
#      27 from .utils import (
#      28     OptionalDependencyNotAvailable,
#      29     _LazyModule,
#    (...)
#      48     logging,
#      49 )
#      52 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File /opt/miniconda3/lib/python3.12/site-packages/transformers/dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)
#      37     "pyyaml",
#      38 ]
#
# File /opt/miniconda3/lib/python3.12/site-packages/transformers/utils/__init__.py:27
#      25 from .. import __version__
#      26 from .backbone_utils import BackboneConfigMixin, BackboneMixin
# ---> 27 from .chat_template_utils import DocstringParsingException, TypeHintParsingException, get_json_schema
#      28 from .constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD, IMAGENET_STANDARD_MEAN, IMAGENET_STANDARD_STD
#      29 from .doc import (
#      30     add_code_sample_docstrings,
#      31     add_end_docstrings,
#    (...)
#      35     replace_return_docstrings,
#      36 )
#
# File /opt/miniconda3/lib/python3.12/site-packages/transformers/utils/chat_template_utils.py:36
#      33     jinja2 = None
#      35 if is_vision_available():
# ---> 36     from PIL.Image import Image
#      38 if is_torch_available():
#      39     from torch import Tensor
#
# File /opt/miniconda3/lib/python3.12/site-packages/PIL/Image.py:97
#      88 MAX_IMAGE_PIXELS: int | None = int(1024 * 1024 * 1024 // 4 // 3)
#      91 try:
#      92     # If the _imaging C module is not present, Pillow will not load.
#      93     # Note that other modules should not refer to _imaging directly;
#      94     # import Image and use the Image.core variable instead.
#      95     # Also note that Image.core is not a publicly documented interface,
#      96     # and should be considered private and subject to change.
# ---> 97     from . import _imaging as core
#      99     if __version__ != getattr(core, "PILLOW_VERSION", None):
#     100         msg = (
#     101             "The _imaging extension was built for another version of Pillow or PIL:\n"
#     102             f"Core version: {getattr(core, 'PILLOW_VERSION', None)}\n"
#     103             f"Pillow version: {__version__}"
#     104         )
#
# KeyboardInterrupt:

# %%
## This time with a wakeup word.

# %%
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import speech_recognition as sr
import pyttsx3
import sounddevice as sd
import numpy as np

# Initialize the text-to-speech engine
engine = pyttsx3.init()

# Set speech rate (optional)
engine.setProperty('rate', 150)

# Check if we can use the GPU on a Mac M1
device = torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")
print(f"Using device: {device}")

# Load the GPT-2 tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2").to(device)
model.eval()

# Speech recognition setup
recognizer = sr.Recognizer()

# Function to convert text to speech
def speak(text):
    engine.say(text)
    engine.runAndWait()

# Function to listen for user input via microphone
def listen():
    with sr.Microphone() as source:
        recognizer.adjust_for_ambient_noise(source)
        print("Listening...")
        audio = recognizer.listen(source)

        try:
            # Recognize the speech
            user_input = recognizer.recognize_google(audio)
            print(f"User: {user_input}")
            return user_input
        except sr.UnknownValueError:
            print("Sorry, I could not understand your speech.")
            return ""
        except sr.RequestError as e:
            print(f"Could not request results from Google Speech Recognition service; {e}")
            return ""

# Function to generate a response using GPT-2
def generate_response(prompt, max_length=100):
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
    outputs = model.generate(inputs, max_length=max_length, pad_token_id=tokenizer.eos_token_id)
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response

# Function to detect the wake word
def listen_for_wake_word(wake_word="matt"):
    while True:
        print(f"Listening for wake word '{wake_word}'...")
        user_input = listen()
        if user_input.lower() == wake_word:
            print(f"Wake word '{wake_word}' detected!")
            return True

# Main conversation loop after wake word is detected
def conversation():
    print("Say something to start the conversation (or 'quit' to exit):")
    while True:
        user_input = listen()
        
        if user_input.lower() == "quit":
            print("Exiting conversation...")
            speak("Goodbye!")
            break

        if user_input:
            # Generate AI response
            gpt_response = generate_response(user_input)
            print(f"AI: {gpt_response}")
            
            # Convert response to speech
            speak(gpt_response)

# Main function to listen for wake word and start conversation
def main():
    while True:
        if listen_for_wake_word(wake_word="matt"):
            conversation()

if __name__ == "__main__":
    main()
# Out:
# Using device: mps
# Listening for wake word 'matt'...
# Listening...
# User: hello how are you
# Listening for wake word 'matt'...
# Listening...
# Sorry, I could not understand your speech.
# Listening for wake word 'matt'...
# Listening...
# User: Matt can you write a code
# Listening for wake word 'matt'...
# Listening...
# User: Matt
# Wake word 'matt' detected!
# Say something to start the conversation (or 'quit' to exit):
# Listening...
# User: write a code
# AI: write a code that will allow you to run the program in a browser.
#
# The code is written in C++, but you can also use the C++ compiler to compile it.
#
# The code is written in C++, but you can also use the C++ compiler to compile it. The code is written in C++, but you can also use the C++ compiler to compile it. The code is written in C++, but you can also use the C++ compiler to
# Listening...
# Sorry, I could not understand your speech.
# Listening...
# Sorry, I could not understand your speech.
# Listening...
# Sorry, I could not understand your speech.
# Listening...
# User: quit
# Exiting conversation...
# Listening for wake word 'matt'...
# Listening...
# Sorry, I could not understand your speech.
# Listening for wake word 'matt'...
# Listening...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 92
#      89             conversation()
#      91 if __name__ == "__main__":
# ---> 92     main()
#
# Cell In[2], line 88, in main()
#      86 def main():
#      87     while True:
# ---> 88         if listen_for_wake_word(wake_word="matt"):
#      89             conversation()
#
# Cell In[2], line 61, in listen_for_wake_word(wake_word)
#      59 while True:
#      60     print(f"Listening for wake word '{wake_word}'...")
# ---> 61     user_input = listen()
#      62     if user_input.lower() == wake_word:
#      63         print(f"Wake word '{wake_word}' detected!")
#
# Cell In[2], line 36, in listen()
#      34 recognizer.adjust_for_ambient_noise(source)
#      35 print("Listening...")
# ---> 36 audio = recognizer.listen(source)
#      38 try:
#      39     # Recognize the speech
#      40     user_input = recognizer.recognize_google(audio)
#
# File ~/miniconda3/lib/python3.10/site-packages/speech_recognition/__init__.py:652, in Recognizer.listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     649 if phrase_time_limit and elapsed_time - phrase_start_time > phrase_time_limit:
#     650     break
# --> 652 buffer = source.stream.read(source.CHUNK)
#     653 if len(buffer) == 0: break  # reached end of the stream
#     654 frames.append(buffer)
#
# File ~/miniconda3/lib/python3.10/site-packages/speech_recognition/__init__.py:161, in Microphone.MicrophoneStream.read(self, size)
#     160 def read(self, size):
# --> 161     return self.pyaudio_stream.read(size, exception_on_overflow=False)
#
# File ~/miniconda3/lib/python3.10/site-packages/pyaudio.py:612, in Stream.read(self, num_frames, exception_on_overflow)
#     608 if not self._is_input:
#     609     raise IOError("Not input stream",
#     610                   paCanNotReadFromAnOutputOnlyStream)
# --> 612 return pa.read_stream(self._stream, num_frames, exception_on_overflow)
#
# KeyboardInterrupt:

# %% [markdown]
# ## This one speaks as well:

# %%
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import speech_recognition as sr
import pyttsx3

# Initialize the text-to-speech engine
engine = pyttsx3.init()

# Set speech rate (optional)
engine.setProperty('rate', 150)

# Check if we can use the GPU on a Mac M1
device = torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")
print(f"Using device: {device}")

# Load the GPT-2 tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2").to(device)
model.eval()

# Speech recognition setup
recognizer = sr.Recognizer()

# Function to convert text to speech
def speak(text):
    print('speak ran')
    engine.say(text)
    engine.runAndWait()

# Function to listen for user input via microphone
def listen():
    with sr.Microphone() as source:
        recognizer.adjust_for_ambient_noise(source)
        print("Listening...")
        audio = recognizer.listen(source)

        try:
            # Recognize the speech
            user_input = recognizer.recognize_google(audio)
            print(f"User: {user_input}")
            return user_input
        except sr.UnknownValueError:
            print("Sorry, I could not understand your speech.")
            return ""
        except sr.RequestError as e:
            print(f"Could not request results from Google Speech Recognition service; {e}")
            return ""

# Function to generate a response using GPT-2
def generate_response(prompt, max_length=100):
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
    outputs = model.generate(inputs, max_length=max_length, pad_token_id=tokenizer.eos_token_id)
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response

# Main conversation loop
def conversation():
    print("Say something to start the conversation (or 'quit' to exit):")
    while True:
        user_input = listen()
        
        if user_input.lower() == "quit":
            print("Exiting...")
            speak("Goodbye!")
            break

        if user_input:
            # Generate AI response
            gpt_response = generate_response(user_input)
            print(f"AI: {gpt_response}")
            
            # Convert response to speech
            speak(gpt_response)

if __name__ == "__main__":
    conversation()
# Out:
# Using device: mps
# /Users/mattsalomon/miniconda3/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1602: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Say something to start the conversation (or 'quit' to exit):
# Listening...
# Sorry, I could not understand your speech.
# Listening...
# User: can you play music
# AI: can you play music with your friends?
#
# I'm not sure if I can play music with my friends. I'm not sure if I can play music with my friends.
#
# I'm not sure if I can play music with my friends. I'm not sure if I can play music with my friends.
#
# I'm not sure if I can play music with my friends. I'm not sure if I can play music with my friends.
#
# I'm not sure if I
# speak ran
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 76
#      73             speak(gpt_response)
#      75 if __name__ == "__main__":
# ---> 76     conversation()
#
# Cell In[11], line 73, in conversation()
#      70 print(f"AI: {gpt_response}")
#      72 # Convert response to speech
# ---> 73 speak(gpt_response)
#
# Cell In[11], line 28, in speak(text)
#      26 print('speak ran')
#      27 engine.say(text)
# ---> 28 engine.runAndWait()
#
# File ~/miniconda3/lib/python3.10/site-packages/pyttsx3/engine.py:186, in Engine.runAndWait(self)
#     184 self._inLoop = True
#     185 self._driverLoop = True
# --> 186 self.proxy.runAndWait()
#
# File ~/miniconda3/lib/python3.10/site-packages/pyttsx3/driver.py:196, in DriverProxy.runAndWait(self)
#     191 """
#     192 Called by the engine to start an event loop, process all commands in
#     193 the queue at the start of the loop, and then exit the loop.
#     194 """
#     195 self._push(self._engine.endLoop, tuple())
# --> 196 self._driver.startLoop()
#
# File ~/miniconda3/lib/python3.10/site-packages/pyttsx3/drivers/nsss.py:71, in NSSpeechDriver.startLoop(self)
#      69 PyObjCAppHelperRunLoopStopper.addRunLoopStopper_toRunLoop_(stopper, runLoop)
#      70 while stopper.shouldRun():
# ---> 71     nextfire = runLoop.limitDateForMode_(NSDefaultRunLoopMode)
#      72     soon = NSDate.dateWithTimeIntervalSinceNow_(0)  # maxTimeout in runConsoleEventLoop
#      73     if nextfire is not None:
#
# KeyboardInterrupt:

# %%
pip install gtts
# Out:
# Collecting gtts
#   Downloading gTTS-2.5.3-py3-none-any.whl (29 kB)
# Requirement already satisfied: requests<3,>=2.27 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from gtts) (2.28.1)
# Requirement already satisfied: click<8.2,>=7.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from gtts) (8.1.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from requests<3,>=2.27->gtts) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from requests<3,>=2.27->gtts) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from requests<3,>=2.27->gtts) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mattsalomon/miniconda3/lib/python3.10/site-packages (from requests<3,>=2.27->gtts) (3.4)
# WARNING: Error parsing requirements for numpy: [Errno 2] No such file or directory: '/Users/mattsalomon/miniconda3/lib/python3.10/site-packages/numpy-1.23.5.dist-info/METADATA'
# Installing collected packages: gtts
# Successfully installed gtts-2.5.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Voice response from the LLM this time with the GTTS module

# %%
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import speech_recognition as sr
from gtts import gTTS
import playsound
import os

# Check if we can use the GPU on a Mac M1
device = torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")
print(f"Using device: {device}")

# Load the GPT-2 tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2").to(device)
model.eval()

# Speech recognition setup
recognizer = sr.Recognizer()

# Function to convert text to speech using gTTS and play it
def speak(text):
    tts = gTTS(text=text, lang='en')
    filename = "temp_audio.mp3"
    tts.save(filename)
    playsound.playsound(filename)
    os.remove(filename)

# Function to listen for user input via microphone
def listen():
    with sr.Microphone() as source:
        recognizer.adjust_for_ambient_noise(source)
        print("Listening...")
        audio = recognizer.listen(source)

        try:
            # Recognize the speech
            user_input = recognizer.recognize_google(audio)
            print(f"User: {user_input}")
            return user_input
        except sr.UnknownValueError:
            print("Sorry, I could not understand your speech.")
            return ""
        except sr.RequestError as e:
            print(f"Could not request results from Google Speech Recognition service; {e}")
            return ""

# Function to generate a response using GPT-2
def generate_response(prompt, max_length=100):
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
    outputs = model.generate(inputs, max_length=max_length, pad_token_id=tokenizer.eos_token_id)
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response

# Main conversation loop
def conversation():
    print("Say something to start the conversation (or 'quit' to exit):")
    while True:
        user_input = listen()
        
        if user_input.lower() == "quit":
            print("Exiting...")
            speak("Goodbye!")
            break

        if user_input:
            # Generate AI response
            gpt_response = generate_response(user_input)
            print(f"AI: {gpt_response}")
            
            # Convert response to speech
            speak(gpt_response)

if __name__ == "__main__":
    conversation()
# Out:
# Using device: mps
# /Users/mattsalomon/miniconda3/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1602: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Say something to start the conversation (or 'quit' to exit):
# Listening...
# User: say hi
# AI: say hi, I'm a little bit of a nerd. I'm a nerd. I'm a nerd. I'm a nerd. I'm a nerd. I'm a nerd. I'm a nerd. I'm a nerd. I'm a nerd. I'm a nerd. I'm a nerd. I'm a nerd. I'm a nerd. I'm a nerd. I'm a nerd. I'm a nerd. I'm a nerd. I'm a nerd. I'm a
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 74
#      71             speak(gpt_response)
#      73 if __name__ == "__main__":
# ---> 74     conversation()
#
# Cell In[10], line 71, in conversation()
#      68 print(f"AI: {gpt_response}")
#      70 # Convert response to speech
# ---> 71 speak(gpt_response)
#
# Cell In[10], line 25, in speak(text)
#      23 filename = "temp_audio.mp3"
#      24 tts.save(filename)
# ---> 25 playsound.playsound(filename)
#      26 os.remove(filename)
#
# File ~/miniconda3/lib/python3.10/site-packages/playsound.py:144, in _playsoundOSX(sound, block)
#     141 nssound.play()
#     143 if block:
# --> 144     sleep(nssound.duration())
#
# KeyboardInterrupt:
